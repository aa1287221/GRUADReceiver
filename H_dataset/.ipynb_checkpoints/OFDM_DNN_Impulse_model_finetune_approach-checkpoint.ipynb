# %%
from __future__ import division
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import tensorflow.compat.v1 as tf
tf.compat.v1.disable_eager_execution()
tf.config.experimental.list_physical_devices('GPU')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' # BE QUIET!!!!

# %% [markdown]
# # Part I : Relevant information

# %%
K = 64 # subcarriers = K
CP = K//4
P = 64 # number of pilot carriers per OFDM block
#pilotValue = 1+1j
allCarriers = np.arange(K)  # indices of all subcarriers ([0, 1, ... K-1])
pilotCarriers = allCarriers[::K//P] # Pilots is every (K/P)th carrier.
#pilotCarriers = np.hstack([pilotCarriers, np.array([allCarriers[-1]])])
#P = P+1
dataCarriers = np.delete(allCarriers, pilotCarriers)
mu = 2    # one symbol combined with two bits for QAM or QPSK (LJS)
payloadBits_per_OFDM = len(dataCarriers)*mu  # number of payload bits per OFDM symbol

payloadBits_per_OFDM = K*mu # payloadbits per OFDM version 2 (decided by how many data carriers per OFDM , LJS)

SNRdb = 25  # signal to noise-ratio in dB at the receiver 

mapping_table = {
    (0,0) : -1-1j,
    (0,1) : -1+1j,
    (1,0) : 1-1j,
    (1,1) : 1+1j,
}

demapping_table = {v : k for k, v in mapping_table.items()}

# %% [markdown]
# # Part II : Define functions

# %%
def Modulation(bits):                                        
    bit_r = bits.reshape((int(len(bits)/mu), mu))                  
    return (2*bit_r[:,0]-1)+1j*(2*bit_r[:,1]-1) # This is just for QAM modulation

def OFDM_symbol(Data, pilot_flag):
    symbol = np.zeros(K, dtype=complex) # the overall K subcarriers
    #symbol = np.zeros(K) 
    symbol[pilotCarriers] = pilotValue  # allocate the pilot subcarriers 
    symbol[dataCarriers] = Data  # allocate the pilot subcarriers
    return symbol

def IDFT(OFDM_data):
    return np.fft.ifft(OFDM_data)   # np.fft.ifft(OFDM_data)*np.sqrt(K)  (lJS)

def addCP(OFDM_time):
    cp = OFDM_time[-CP:] # take the last CP samples ...
    return np.hstack([cp, OFDM_time])  # ... and add them to the beginning

def channel_AWGN(signal,channelResponse,SNRdb):          # construct the another version is including impulse noise(LJS)
    # AWGN channel
    convolved = np.convolve(signal, channelResponse)
    signal_power = np.mean(abs(convolved**2))
    sigma2 = signal_power * 10**(-SNRdb/10)  
    noise = np.sqrt(sigma2/2) * (np.random.randn(*convolved.shape)+1j*np.random.randn(*convolved.shape))
    return convolved + noise

def channel_BG(signal,channelResponse,SNRdb):            # construct the another version is including impulse noise(LJS)
    # Bernoulli-Gaussian channel          # lJS
    prob=0.001 #prob
    convolved = np.convolve(signal, channelResponse)
    signal_power = np.mean(abs(convolved**2))
    sigma2 = signal_power * 10**(-SNRdb/10)      # (signal_power/2)  (LJS)
    sigma3 = 2
    Gaussian=np.random.randn(*convolved.shape)+1j*np.random.randn(*convolved.shape)
    power1=np.zeros([*convolved.shape])
    for i in range(*convolved.shape):
        k=np.random.rand()
        if k >  prob :
            power1[i]=np.sqrt(sigma2/2)
        if k <= prob :
            power1[i]=np.sqrt(sigma3/2)
    power2=np.zeros([*convolved.shape])
    for i in range(*convolved.shape):
        k=np.random.rand()
        if k >  prob :
            power2[i]=np.sqrt(sigma2/2)
        if k <= prob :
            power2[i]=np.sqrt(sigma3/2)
    noise1=np.multiply(power1,Gaussian.real)
    noise2=np.multiply(power2,Gaussian.imag)
    noise_BG=np.zeros([*convolved.shape]).astype(complex)
    noise_BG.real=noise1
    noise_BG.imag=noise2
    return convolved + noise_BG

def removeCP(signal):
    return signal[CP:(CP+K)]

def equalize(OFDM_demod, Hest):   # *(LJS)
    return OFDM_demod / Hest

def get_payload(equalized):       # **(LJS)
    return equalized[dataCarriers]

def PS(bits):                     # *(LJS)
    return bits.reshape((-1,))

def clipper(OFDM_RX_noCP):         # LJS
    clipper_threshold=0.15         # initial value = 0.1 : 0.05 : 0.5
    norm=np.abs(OFDM_RX_noCP)
    angle=np.angle(OFDM_RX_noCP)
    for i in range(*OFDM_RX_noCP.shape):
        if norm[i] >= clipper_threshold:
            OFDM_RX_noCP.real[i]=clipper_threshold*np.cos(angle[i])
            OFDM_RX_noCP.imag[i]=clipper_threshold*np.sin(angle[i])
    return OFDM_RX_noCP

def ofdm_simulate_AWGN(codeword, channelResponse,SNRdb):       # LJS
    OFDM_data = np.zeros(K, dtype=complex)
    OFDM_data[allCarriers] = pilotValue
    OFDM_time = IDFT(OFDM_data)
    OFDM_withCP = addCP(OFDM_time)
    OFDM_TX = OFDM_withCP
    OFDM_RX = channel_AWGN(OFDM_TX, channelResponse,SNRdb)
    OFDM_RX_noCP = removeCP(OFDM_RX)
    # ----- target inputs ---
    symbol = np.zeros(K, dtype=complex)
    codeword_qam = Modulation(codeword)
    symbol[np.arange(K)] = codeword_qam
    OFDM_data_codeword = symbol
    OFDM_time_codeword = np.fft.ifft(OFDM_data_codeword)
    OFDM_withCP_cordword = addCP(OFDM_time_codeword)
    OFDM_RX_codeword = channel_AWGN(OFDM_withCP_cordword, channelResponse,SNRdb)
    OFDM_RX_noCP_codeword = removeCP(OFDM_RX_codeword)
    return np.concatenate((np.concatenate((np.real(OFDM_RX_noCP),np.imag(OFDM_RX_noCP))), np.concatenate((np.real(OFDM_RX_noCP_codeword),np.imag(OFDM_RX_noCP_codeword))))), abs(channelResponse) 

def ofdm_simulate_BG(codeword, channelResponse,SNRdb):       # LJS
    OFDM_data = np.zeros(K, dtype=complex)
    OFDM_data[allCarriers] = pilotValue
    OFDM_time = IDFT(OFDM_data)
    OFDM_withCP = addCP(OFDM_time)
    OFDM_TX = OFDM_withCP
    OFDM_RX = channel_BG(OFDM_TX, channelResponse,SNRdb)
    OFDM_RX_noCP = removeCP(OFDM_RX)
    # ----- target inputs ---
    symbol = np.zeros(K, dtype=complex)
    codeword_qam = Modulation(codeword)
    symbol[np.arange(K)] = codeword_qam
    OFDM_data_codeword = symbol
    OFDM_time_codeword = np.fft.ifft(OFDM_data_codeword)
    OFDM_withCP_cordword = addCP(OFDM_time_codeword)
    OFDM_RX_codeword = channel_BG(OFDM_withCP_cordword, channelResponse,SNRdb)
    OFDM_RX_noCP_codeword = removeCP(OFDM_RX_codeword)
    return np.concatenate((np.concatenate((np.real(OFDM_RX_noCP),np.imag(OFDM_RX_noCP))), np.concatenate((np.real(OFDM_RX_noCP_codeword),np.imag(OFDM_RX_noCP_codeword))))), abs(channelResponse) 

def ofdm_simulate_clip(codeword, channelResponse,SNRdb):       # LJS
    OFDM_data = np.zeros(K, dtype=complex)
    OFDM_data[allCarriers] = pilotValue
    OFDM_time = IDFT(OFDM_data)
    OFDM_withCP = addCP(OFDM_time)
    OFDM_TX = OFDM_withCP
    OFDM_RX = channel(OFDM_TX, channelResponse,SNRdb)
    OFDM_RX_noCP = removeCP(OFDM_RX)
    OFDM_RX_noCP_clip = clipper(OFDM_RX_noCP)  # LJS
    # ----- target inputs ---
    symbol = np.zeros(K, dtype=complex)
    codeword_qam = Modulation(codeword)
    symbol[np.arange(K)] = codeword_qam
    OFDM_data_codeword = symbol
    OFDM_time_codeword = np.fft.ifft(OFDM_data_codeword)
    OFDM_withCP_cordword = addCP(OFDM_time_codeword)
    OFDM_RX_codeword = channel(OFDM_withCP_cordword, channelResponse,SNRdb)
    OFDM_RX_noCP_codeword = removeCP(OFDM_RX_codeword)
    OFDM_RX_noCP_codeword_clip = clipper(OFDM_RX_noCP_codeword)  # LJS
    return np.concatenate((np.concatenate((np.real(OFDM_RX_noCP_clip),np.imag(OFDM_RX_noCP_clip))), np.concatenate((np.real(OFDM_RX_noCP_codeword_clip),np.imag(OFDM_RX_noCP_codeword_clip))))), abs(channelResponse) 

def decision(y_pred_np,batch_y):       # LJS
    size=np.shape(batch_y)   
    y_pred_trans=np.zeros([size[0],size[1]])
    for k in range(size[0]):
        for p in range(size[1]):
            if y_pred_np[k,p] > 0.5 :
                y_pred_trans[k,p] = 1
            if y_pred_np[k,p] < 0.5 :
                y_pred_trans[k,p] = 0
            if y_pred_np[k,p] == 0.5 :
                y_pred_trans[k,p] = np.random.randint(0,2)    
    count=0
    for i in range(size[0]):
        for j in range(size[1]):
            if y_pred_trans[i,j] != batch_y[i,j]:
                count=count+1                            
    BER=count/(size[0]*size[1])
    return BER

Pilot_file_name = 'Pilot_'+str(P)   # Here file name is "Pilot_64" (LJS)
if os.path.isfile(Pilot_file_name):
    print ('Load Training Pilots txt')
    # load file
    bits = np.loadtxt(Pilot_file_name, delimiter=',')
else:
    # write file
    bits = np.random.binomial(n=1, p=0.5, size=(K*mu, ))
    np.savetxt(Pilot_file_name, bits, delimiter=',')

pilotValue = Modulation(bits)
# Out:
# Load Training Pilots txt

# %% [markdown]
# # Part III : Deep learning training

# %%
# %%time
# Training parameters
# training_epochs = 20
# batch_size = 256
display_step = 100  #5
test_step = 200
cost_step = 25  # LJS
# examples_to_show = 10  
# Network Parameters
n_hidden_1 = 500
n_hidden_2 = 250 # 1st layer num features
n_hidden_3 = 120 # 2nd layer num features
n_input = 256  
n_output = 16 # every 16 bit are predicted by a model
# tf Graph input (only pictures)
X = tf.placeholder("float", [None, n_input])
Y = tf.placeholder("float", [None, n_output])

weights = {                    
    'encoder_h1': tf.Variable(tf.truncated_normal([n_input, n_hidden_1],stddev=0.1)),
    'encoder_h2': tf.Variable(tf.truncated_normal([n_hidden_1, n_hidden_2],stddev=0.1)),
    'encoder_h3': tf.Variable(tf.truncated_normal([n_hidden_2, n_hidden_3],stddev=0.1)),
    'encoder_h4': tf.Variable(tf.truncated_normal([n_hidden_3, n_output],stddev=0.1)),            
}
biases = {            
    'encoder_b1': tf.Variable(tf.truncated_normal([n_hidden_1],stddev=0.1)),
    'encoder_b2': tf.Variable(tf.truncated_normal([n_hidden_2],stddev=0.1)),
    'encoder_b3': tf.Variable(tf.truncated_normal([n_hidden_3],stddev=0.1)),
    'encoder_b4': tf.Variable(tf.truncated_normal([n_output],stddev=0.1)),          

}

# Encoder Hidden layer with sigmoid activation # 1
# layer_1 = tf.nn.sigmoid(tf.add(tf.matmul(x, weights['encoder_h1']), biases['encoder_b1']))
layer_1 = tf.nn.relu(tf.add(tf.matmul(X, weights['encoder_h1']), biases['encoder_b1']))
layer_2 = tf.nn.relu(tf.add(tf.matmul(layer_1, weights['encoder_h2']), biases['encoder_b2']))
layer_3 = tf.nn.relu(tf.add(tf.matmul(layer_2, weights['encoder_h3']), biases['encoder_b3']))
layer_4 = tf.nn.sigmoid(tf.add(tf.matmul(layer_3, weights['encoder_h4']), biases['encoder_b4']))
       
y_pred = layer_4
# Targets (Labels) are the input data.
y_true = Y

# Define loss and optimizer, minimize the squared error
cost = tf.reduce_mean(tf.pow(y_true - y_pred, 2))
learning_rate = tf.placeholder(tf.float32, shape=[])
optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate).minimize(cost)

# Initializing the variables
init = tf.global_variables_initializer()

# Start Training
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
# The H information set
H_folder_train = '../H_dataset/train/'
H_folder_test = '../H_dataset/test/'
train_idx_low = 1
train_idx_high = 301
test_idx_low = 301
test_idx_high = 401

# =================== Saving Channel conditions to a large matrix ================ #
channel_response_set_train = []
for train_idx in range(train_idx_low,train_idx_high):
    print("Processing the train", train_idx, "th document")
    H_file = H_folder_train + str(train_idx) + '.txt'
    with open(H_file) as f:
        for line in f:
            numbers_str = line.split()
            # np.shape(numbers_str)=32 x 1
            numbers_float = [float(x) for x in numbers_str]
            # np.shape(numbers_float)=32 x 1
            h_response = np.asarray(numbers_float[0:int(len(numbers_float)/2)])+\
            1j*np.asarray(numbers_float[int(len(numbers_float)/2):len(numbers_float)])
            channel_response_set_train.append(h_response)
        
channel_response_set_test = []
for test_idx in range(test_idx_low,test_idx_high):
    print("Processing the test", test_idx, "th document")
    H_file = H_folder_test + str(test_idx) + '.txt'
    with open(H_file) as f:
        for line in f:
            numbers_str = line.split()
            numbers_float = [float(x) for x in numbers_str]
            h_response = np.asarray(numbers_float[0:int(len(numbers_float)/2)])+\
            1j*np.asarray(numbers_float[int(len(numbers_float)/2):len(numbers_float)])
            channel_response_set_test.append(h_response)
            # print(np.shape(channel_response_set_test))

print ('length of training channel response is', len(channel_response_set_train))
print ('length of testing channel response is', len(channel_response_set_test))
print ('shape of training channel response is', np.shape(channel_response_set_train))
print ('shape of testing channel response is', np.shape(channel_response_set_test))
#=================== end ================ #

with tf.Session(config=config) as sess:
    sess.run(init)
    training_epochs = 5000 #20000
    learning_rate_current = 0.001   #0.01
    training_cost=np.zeros([1,200]) # LJS
    for epoch in range(training_epochs):
        print ("========================================")
        print('Processing the',epoch+1,'th epoch')
#         if epoch > 0 and epoch % 500 == 0: # 2000
#             learning_rate_current = learning_rate_current/5                    
        avg_cost = 0.0
        total_batch = 50   #50        
        
        if epoch <= 2000 :
            print('learning rate' , learning_rate_current)
            for index_m in range(total_batch):
                input_samples = []
                input_labels = []
                for index_k in range(0, 500):     #1000
                    bits = np.random.binomial(n=1, p=0.5, size=(payloadBits_per_OFDM, ))      
                    channel_response = channel_response_set_train[np.random.randint(0,len(channel_response_set_train))]      
                    signal_output, para = ofdm_simulate_AWGN(bits,channel_response,SNRdb)   
                    input_labels.append(bits[16:32]) 
                    input_samples.append(signal_output)
                batch_x = np.asarray(input_samples)     
                batch_y = np.asarray(input_labels)
                _,c = sess.run([optimizer,cost], feed_dict={X:batch_x,# input
                                                            Y:batch_y,# labels
                                                            learning_rate:learning_rate_current})
                avg_cost += c / total_batch
                
        if epoch >  2000 : 
            if epoch % cost_step == 0 :
                learning_rate_current = learning_rate_current-0.00001
                if learning_rate_current <= 0.00001 :
                    learning_rate_current = 0.00001
                print('learning rate' , learning_rate_current)
            for index_m in range(total_batch):
                input_samples = []
                input_labels = []
                for index_k in range(0, 500):     #1000
                    bits = np.random.binomial(n=1, p=0.5, size=(payloadBits_per_OFDM, ))      
                    channel_response = channel_response_set_train[np.random.randint(0,len(channel_response_set_train))]      
                    signal_output, para = ofdm_simulate_BG(bits,channel_response,SNRdb)   
                    input_labels.append(bits[16:32]) 
                    input_samples.append(signal_output)
                batch_x = np.asarray(input_samples)     
                batch_y = np.asarray(input_labels)
                _,c = sess.run([optimizer,cost], feed_dict={X:batch_x,# input
                                                            Y:batch_y,# labels
                                                            learning_rate:learning_rate_current})
                avg_cost += c / total_batch
        
        if epoch % cost_step == 0 :
            training_cost[0,epoch//cost_step] = avg_cost  
            
#         if learning_rate_current <= 0.00001 :
#             break
            
        if epoch % display_step == 0:  # == 0
            print("epoch:",'%04d' % (epoch+1))
            print("cost=", "{:.9f}".format(avg_cost))
            #print ("========================================")
            input_samples_test = []
            input_labels_test = []
            test_number = 1  #1000
            # set test channel response for this epoch                    
            if epoch % test_step == 0: 
                #print ("========================================")
                print ("This is a Big Test Set ")
                test_number = 1  # 10000
            for i in range(0, test_number):
                bits = np.random.binomial(n=1, p=0.5, size=(payloadBits_per_OFDM, ))  
                channel_response= channel_response_set_test[np.random.randint(0,len(channel_response_set_test))]
                signal_output, para = ofdm_simulate_BG(bits,channel_response,SNRdb)
                input_labels_test.append(bits[16:32])
                input_samples_test.append(signal_output)

            batch_x = np.asarray(input_samples_test)
            batch_y = np.asarray(input_labels_test)
            # encode_decode = sess.run(y_pred, feed_dict = {X:batch_x})
            mean_error = tf.reduce_mean(abs(y_pred - batch_y))
            mean_error_rate = 1-tf.reduce_mean(tf.reduce_mean(tf.to_float(tf.equal(tf.sign(y_pred-0.5), tf.cast(tf.sign(batch_y-0.5),tf.float32))),1))               
            # print("OFDM Detection QAM output number is", n_output, ",SNR = ", SNRdb, ",Num Pilot = ", P,", prediction and the mean error on test set are:", mean_error.eval({X:batch_x}), mean_error_rate.eval({X:batch_x}))
            print("OFDM Detection QAM output number is", n_output)
            print("SNR = ", SNRdb)
            print("Num Pilot", P)
            print("prediction and the mean error on test set are:", 
                  mean_error.eval({X:batch_x}), mean_error_rate.eval({X:batch_x}))
            y_pred_np=y_pred.eval({X:batch_x})  # LJS
            BER=decision(y_pred_np,batch_y)     # LJS
            print('BER :',BER)                  # LJS

            batch_x = np.asarray(input_samples)
            batch_y = np.asarray(input_labels)
            # encode_decode = sess.run(y_pred, feed_dict = {X:batch_x})
            mean_error = tf.reduce_mean(abs(y_pred - batch_y))                    
            mean_error_rate = 1-tf.reduce_mean(tf.reduce_mean(tf.to_float(tf.equal(tf.sign(y_pred-0.5), tf.cast(tf.sign(batch_y-0.5),tf.float32))),1))
            print("Prediction and the mean error on train set are:",\
                  mean_error.eval({X:batch_x}), mean_error_rate.eval({X:batch_x}))
            #print ("========================================")
    print("Total epochs cost : \n",training_cost)  # LJS
    print("optimization finished")
    # save the model
    saver = tf.train.Saver()
    save_path = saver.save(sess, "net_Impulse_thesis/epochs_5000.ckpt")
    print("Save to path: ", save_path)
# Out:
# Processing the train 1 th document
# Processing the train 2 th document
# Processing the train 3 th document
# Processing the train 4 th document
# Processing the train 5 th document
# Processing the train 6 th document
# Processing the train 7 th document
# Processing the train 8 th document
# Processing the train 9 th document
# Processing the train 10 th document
# Processing the train 11 th document
# Processing the train 12 th document
# Processing the train 13 th document
# Processing the train 14 th document
# Processing the train 15 th document
# Processing the train 16 th document
# Processing the train 17 th document
# Processing the train 18 th document
# Processing the train 19 th document
# Processing the train 20 th document
# Processing the train 21 th document
# Processing the train 22 th document
# Processing the train 23 th document
# Processing the train 24 th document
# Processing the train 25 th document
# Processing the train 26 th document
# Processing the train 27 th document
# Processing the train 28 th document
# Processing the train 29 th document
# Processing the train 30 th document
# Processing the train 31 th document
# Processing the train 32 th document
# Processing the train 33 th document
# Processing the train 34 th document
# Processing the train 35 th document
# Processing the train 36 th document
# Processing the train 37 th document
# Processing the train 38 th document
# Processing the train 39 th document
# Processing the train 40 th document
# Processing the train 41 th document
# Processing the train 42 th document
# Processing the train 43 th document
# Processing the train 44 th document
# Processing the train 45 th document
# Processing the train 46 th document
# Processing the train 47 th document
# Processing the train 48 th document
# Processing the train 49 th document
# Processing the train 50 th document
# Processing the train 51 th document
# Processing the train 52 th document
# Processing the train 53 th document
# Processing the train 54 th document
# Processing the train 55 th document
# Processing the train 56 th document
# Processing the train 57 th document
# Processing the train 58 th document
# Processing the train 59 th document
# Processing the train 60 th document
# Processing the train 61 th document
# Processing the train 62 th document
# Processing the train 63 th document
# Processing the train 64 th document
# Processing the train 65 th document
# Processing the train 66 th document
# Processing the train 67 th document
# Processing the train 68 th document
# Processing the train 69 th document
# Processing the train 70 th document
# Processing the train 71 th document
# Processing the train 72 th document
# Processing the train 73 th document
# Processing the train 74 th document
# Processing the train 75 th document
# Processing the train 76 th document
# Processing the train 77 th document
# Processing the train 78 th document
# Processing the train 79 th document
# Processing the train 80 th document
# Processing the train 81 th document
# Processing the train 82 th document
# Processing the train 83 th document
# Processing the train 84 th document
# Processing the train 85 th document
# Processing the train 86 th document
# Processing the train 87 th document
# Processing the train 88 th document
# Processing the train 89 th document
# Processing the train 90 th document
# Processing the train 91 th document
# Processing the train 92 th document
# Processing the train 93 th document
# Processing the train 94 th document
# Processing the train 95 th document
# Processing the train 96 th document
# Processing the train 97 th document
# Processing the train 98 th document
# Processing the train 99 th document
# Processing the train 100 th document
# Processing the train 101 th document
# Processing the train 102 th document
# Processing the train 103 th document
# Processing the train 104 th document
# Processing the train 105 th document
# Processing the train 106 th document
# Processing the train 107 th document
# Processing the train 108 th document
# Processing the train 109 th document
# Processing the train 110 th document
# Processing the train 111 th document
# Processing the train 112 th document
# Processing the train 113 th document
# Processing the train 114 th document
# Processing the train 115 th document
# Processing the train 116 th document
# Processing the train 117 th document
# Processing the train 118 th document
# Processing the train 119 th document
# Processing the train 120 th document
# Processing the train 121 th document
# Processing the train 122 th document
# Processing the train 123 th document
# Processing the train 124 th document
# Processing the train 125 th document
# Processing the train 126 th document
# Processing the train 127 th document
# Processing the train 128 th document
# Processing the train 129 th document
# Processing the train 130 th document
# Processing the train 131 th document
# Processing the train 132 th document
# Processing the train 133 th document
# Processing the train 134 th document
# Processing the train 135 th document
# Processing the train 136 th document
# Processing the train 137 th document
# Processing the train 138 th document
# Processing the train 139 th document
# Processing the train 140 th document
# Processing the train 141 th document
# Processing the train 142 th document
# Processing the train 143 th document
# Processing the train 144 th document
# Processing the train 145 th document
# Processing the train 146 th document
# Processing the train 147 th document
# Processing the train 148 th document
# Processing the train 149 th document
# Processing the train 150 th document
# Processing the train 151 th document
# Processing the train 152 th document
# Processing the train 153 th document
# Processing the train 154 th document
# Processing the train 155 th document
# Processing the train 156 th document
# Processing the train 157 th document
# Processing the train 158 th document
# Processing the train 159 th document
# Processing the train 160 th document
# Processing the train 161 th document
# Processing the train 162 th document
# Processing the train 163 th document
# Processing the train 164 th document
# Processing the train 165 th document
# Processing the train 166 th document
# Processing the train 167 th document
# Processing the train 168 th document
# Processing the train 169 th document
# Processing the train 170 th document
# Processing the train 171 th document
# Processing the train 172 th document
# Processing the train 173 th document
# Processing the train 174 th document
# Processing the train 175 th document
# Processing the train 176 th document
# Processing the train 177 th document
# Processing the train 178 th document
# Processing the train 179 th document
# Processing the train 180 th document
# Processing the train 181 th document
# Processing the train 182 th document
# Processing the train 183 th document
# Processing the train 184 th document
# Processing the train 185 th document
# Processing the train 186 th document
# Processing the train 187 th document
# Processing the train 188 th document
# Processing the train 189 th document
# Processing the train 190 th document
# Processing the train 191 th document
# Processing the train 192 th document
# Processing the train 193 th document
# Processing the train 194 th document
# Processing the train 195 th document
# Processing the train 196 th document
# Processing the train 197 th document
# Processing the train 198 th document
# Processing the train 199 th document
# Processing the train 200 th document
# Processing the train 201 th document
# Processing the train 202 th document
# Processing the train 203 th document
# Processing the train 204 th document
# Processing the train 205 th document
# Processing the train 206 th document
# Processing the train 207 th document
# Processing the train 208 th document
# Processing the train 209 th document
# Processing the train 210 th document
# Processing the train 211 th document
# Processing the train 212 th document
# Processing the train 213 th document
# Processing the train 214 th document
# Processing the train 215 th document
# Processing the train 216 th document
# Processing the train 217 th document
# Processing the train 218 th document
# Processing the train 219 th document
# Processing the train 220 th document
# Processing the train 221 th document
# Processing the train 222 th document
# Processing the train 223 th document
# Processing the train 224 th document
# Processing the train 225 th document
# Processing the train 226 th document
# Processing the train 227 th document
# Processing the train 228 th document
# Processing the train 229 th document
# Processing the train 230 th document
# Processing the train 231 th document
# Processing the train 232 th document
# Processing the train 233 th document
# Processing the train 234 th document
# Processing the train 235 th document
# Processing the train 236 th document
# Processing the train 237 th document
# Processing the train 238 th document
# Processing the train 239 th document
# Processing the train 240 th document
# Processing the train 241 th document
# Processing the train 242 th document
# Processing the train 243 th document
# Processing the train 244 th document
# Processing the train 245 th document
# Processing the train 246 th document
# Processing the train 247 th document
# Processing the train 248 th document
# Processing the train 249 th document
# Processing the train 250 th document
# Processing the train 251 th document
# Processing the train 252 th document
# Processing the train 253 th document
# Processing the train 254 th document
# Processing the train 255 th document
# Processing the train 256 th document
# Processing the train 257 th document
# Processing the train 258 th document
# Processing the train 259 th document
# Processing the train 260 th document
# Processing the train 261 th document
# Processing the train 262 th document
# Processing the train 263 th document
# Processing the train 264 th document
# Processing the train 265 th document
# Processing the train 266 th document
# Processing the train 267 th document
# Processing the train 268 th document
# Processing the train 269 th document
# Processing the train 270 th document
# Processing the train 271 th document
# Processing the train 272 th document
# Processing the train 273 th document
# Processing the train 274 th document
# Processing the train 275 th document
# Processing the train 276 th document
# Processing the train 277 th document
# Processing the train 278 th document
# Processing the train 279 th document
# Processing the train 280 th document
# Processing the train 281 th document
# Processing the train 282 th document
# Processing the train 283 th document
# Processing the train 284 th document
# Processing the train 285 th document
# Processing the train 286 th document
# Processing the train 287 th document
# Processing the train 288 th document
# Processing the train 289 th document
# Processing the train 290 th document
# Processing the train 291 th document
# Processing the train 292 th document
# Processing the train 293 th document
# Processing the train 294 th document
# Processing the train 295 th document
# Processing the train 296 th document
# Processing the train 297 th document
# Processing the train 298 th document
# Processing the train 299 th document
# Processing the train 300 th document
# Processing the test 301 th document
# Processing the test 302 th document
# Processing the test 303 th document
# Processing the test 304 th document
# Processing the test 305 th document
# Processing the test 306 th document
# Processing the test 307 th document
# Processing the test 308 th document
# Processing the test 309 th document
# Processing the test 310 th document
# Processing the test 311 th document
# Processing the test 312 th document
# Processing the test 313 th document
# Processing the test 314 th document
# Processing the test 315 th document
# Processing the test 316 th document
# Processing the test 317 th document
# Processing the test 318 th document
# Processing the test 319 th document
# Processing the test 320 th document
# Processing the test 321 th document
# Processing the test 322 th document
# Processing the test 323 th document
# Processing the test 324 th document
# Processing the test 325 th document
# Processing the test 326 th document
# Processing the test 327 th document
# Processing the test 328 th document
# Processing the test 329 th document
# Processing the test 330 th document
# Processing the test 331 th document
# Processing the test 332 th document
# Processing the test 333 th document
# Processing the test 334 th document
# Processing the test 335 th document
# Processing the test 336 th document
# Processing the test 337 th document
# Processing the test 338 th document
# Processing the test 339 th document
# Processing the test 340 th document
# Processing the test 341 th document
# Processing the test 342 th document
# Processing the test 343 th document
# Processing the test 344 th document
# Processing the test 345 th document
# Processing the test 346 th document
# Processing the test 347 th document
# Processing the test 348 th document
# Processing the test 349 th document
# Processing the test 350 th document
# Processing the test 351 th document
# Processing the test 352 th document
# Processing the test 353 th document
# Processing the test 354 th document
# Processing the test 355 th document
# Processing the test 356 th document
# Processing the test 357 th document
# Processing the test 358 th document
# Processing the test 359 th document
# Processing the test 360 th document
# Processing the test 361 th document
# Processing the test 362 th document
# Processing the test 363 th document
# Processing the test 364 th document
# Processing the test 365 th document
# Processing the test 366 th document
# Processing the test 367 th document
# Processing the test 368 th document
# Processing the test 369 th document
# Processing the test 370 th document
# Processing the test 371 th document
# Processing the test 372 th document
# Processing the test 373 th document
# Processing the test 374 th document
# Processing the test 375 th document
# Processing the test 376 th document
# Processing the test 377 th document
# Processing the test 378 th document
# Processing the test 379 th document
# Processing the test 380 th document
# Processing the test 381 th document
# Processing the test 382 th document
# Processing the test 383 th document
# Processing the test 384 th document
# Processing the test 385 th document
# Processing the test 386 th document
# Processing the test 387 th document
# Processing the test 388 th document
# Processing the test 389 th document
# Processing the test 390 th document
# Processing the test 391 th document
# Processing the test 392 th document
# Processing the test 393 th document
# Processing the test 394 th document
# Processing the test 395 th document
# Processing the test 396 th document
# Processing the test 397 th document
# Processing the test 398 th document
# Processing the test 399 th document
# Processing the test 400 th document
# length of training channel response is 3000000
# length of testing channel response is 1000000
# shape of training channel response is (3000000, 16)
# shape of testing channel response is (1000000, 16)
# ========================================
# Processing the 1 th epoch
# learning rate 0.001
# epoch: 0001
# cost= 0.252912001
# This is a Big Test Set
# OFDM Detection QAM output number is 16
# SNR =  25
# Num Pilot 64
# prediction and the mean error on test set are: 0.5052768 0.625
# BER : 0.625
# Prediction and the mean error on train set are: 0.4994383 0.49550003
# ========================================
# Processing the 2 th epoch
# learning rate 0.001
# ========================================
# Processing the 3 th epoch
# learning rate 0.001
# ========================================
# Processing the 4 th epoch
# learning rate 0.001
# ========================================
# Processing the 5 th epoch
# learning rate 0.001
# ========================================
# Processing the 6 th epoch
# learning rate 0.001
# ========================================
# Processing the 7 th epoch
# learning rate 0.001
# ========================================
# Processing the 8 th epoch
# learning rate 0.001
# ========================================
# Processing the 9 th epoch
# learning rate 0.001
# ========================================
# Processing the 10 th epoch
# learning rate 0.001
# ========================================
# Processing the 11 th epoch
# learning rate 0.001
# ========================================
# Processing the 12 th epoch
# learning rate 0.001
# ========================================
# Processing the 13 th epoch
# learning rate 0.001
# ========================================
# Processing the 14 th epoch
# learning rate 0.001
# ========================================
# Processing the 15 th epoch
# learning rate 0.001
# ========================================
# Processing the 16 th epoch
# learning rate 0.001
# ========================================
# Processing the 17 th epoch
# learning rate 0.001
# ========================================
# Processing the 18 th epoch
# learning rate 0.001
# ========================================
# Processing the 19 th epoch
# learning rate 0.001
# ========================================
# Processing the 20 th epoch
# learning rate 0.001
# ========================================
# Processing the 21 th epoch
# learning rate 0.001
# ========================================
# Processing the 22 th epoch
# learning rate 0.001
# ========================================
# Processing the 23 th epoch
# learning rate 0.001
# ========================================
# Processing the 24 th epoch
# learning rate 0.001
# ========================================
# Processing the 25 th epoch
# learning rate 0.001
# ========================================
# Processing the 26 th epoch
# learning rate 0.001
# ========================================
# Processing the 27 th epoch
# learning rate 0.001
# ========================================
# Processing the 28 th epoch
# learning rate 0.001
# ========================================
# Processing the 29 th epoch
# learning rate 0.001
# ========================================
# Processing the 30 th epoch
# learning rate 0.001
# ========================================
# Processing the 31 th epoch
# learning rate 0.001
# ========================================
# Processing the 32 th epoch
# learning rate 0.001
# ========================================
# Processing the 33 th epoch
# learning rate 0.001
# ========================================
# Processing the 34 th epoch
# learning rate 0.001
# ========================================
# Processing the 35 th epoch
# learning rate 0.001
# ========================================
# Processing the 36 th epoch
# learning rate 0.001
# ========================================
# Processing the 37 th epoch
# learning rate 0.001
# ========================================
# Processing the 38 th epoch
# learning rate 0.001
# ========================================
# Processing the 39 th epoch
# learning rate 0.001
# ========================================
# Processing the 40 th epoch
# learning rate 0.001
# ========================================
# Processing the 41 th epoch
# learning rate 0.001
# ========================================
# Processing the 42 th epoch
# learning rate 0.001
# ========================================
# Processing the 43 th epoch
# learning rate 0.001
# ========================================
# Processing the 44 th epoch
# learning rate 0.001
# ========================================
# Processing the 45 th epoch
# learning rate 0.001
# ========================================
# Processing the 46 th epoch
# learning rate 0.001
# ========================================
# Processing the 47 th epoch
# learning rate 0.001
# ========================================
# Processing the 48 th epoch
# learning rate 0.001
# ========================================
# Processing the 49 th epoch
# learning rate 0.001
# ========================================
# Processing the 50 th epoch
# learning rate 0.001
# ========================================
# Processing the 51 th epoch
# learning rate 0.001
# ========================================
# Processing the 52 th epoch
# learning rate 0.001
# ========================================
# Processing the 53 th epoch
# learning rate 0.001
# ========================================
# Processing the 54 th epoch
# learning rate 0.001
# ========================================
# Processing the 55 th epoch
# learning rate 0.001
# ========================================
# Processing the 56 th epoch
# learning rate 0.001
# ========================================
# Processing the 57 th epoch
# learning rate 0.001
# ========================================
# Processing the 58 th epoch
# learning rate 0.001
# ========================================
# Processing the 59 th epoch
# learning rate 0.001
# ========================================
# Processing the 60 th epoch
# learning rate 0.001
# ========================================
# Processing the 61 th epoch
# learning rate 0.001
# ========================================
# Processing the 62 th epoch
# learning rate 0.001
# ========================================
# Processing the 63 th epoch
# learning rate 0.001
# ========================================
# Processing the 64 th epoch
# learning rate 0.001
# ========================================
# Processing the 65 th epoch
# learning rate 0.001
# ========================================
# Processing the 66 th epoch
# learning rate 0.001
# ========================================
# Processing the 67 th epoch
# learning rate 0.001
# ========================================
# Processing the 68 th epoch
# learning rate 0.001
# ========================================
# Processing the 69 th epoch
# learning rate 0.001
# ========================================
# Processing the 70 th epoch
# learning rate 0.001
# ========================================
# Processing the 71 th epoch
# learning rate 0.001
# ========================================
# Processing the 72 th epoch
# learning rate 0.001
# ========================================
# Processing the 73 th epoch
# learning rate 0.001
# ========================================
# Processing the 74 th epoch
# learning rate 0.001
# ========================================
# Processing the 75 th epoch
# learning rate 0.001
# ========================================
# Processing the 76 th epoch
# learning rate 0.001
# ========================================
# Processing the 77 th epoch
# learning rate 0.001
# ========================================
# Processing the 78 th epoch
# learning rate 0.001
# ========================================
# Processing the 79 th epoch
# learning rate 0.001
# ========================================
# Processing the 80 th epoch
# learning rate 0.001
# ========================================
# Processing the 81 th epoch
# learning rate 0.001
# ========================================
# Processing the 82 th epoch
# learning rate 0.001
# ========================================
# Processing the 83 th epoch
# learning rate 0.001
# ========================================
# Processing the 84 th epoch
# learning rate 0.001
# ========================================
# Processing the 85 th epoch
# learning rate 0.001
# ========================================
# Processing the 86 th epoch
# learning rate 0.001
# ========================================
# Processing the 87 th epoch
# learning rate 0.001
# ========================================
# Processing the 88 th epoch
# learning rate 0.001
# ========================================
# Processing the 89 th epoch
# learning rate 0.001
# ========================================
# Processing the 90 th epoch
# learning rate 0.001
# ========================================
# Processing the 91 th epoch
# learning rate 0.001
# ========================================
# Processing the 92 th epoch
# learning rate 0.001
# ========================================
# Processing the 93 th epoch
# learning rate 0.001
# ========================================
# Processing the 94 th epoch
# learning rate 0.001
# ========================================
# Processing the 95 th epoch
# learning rate 0.001
# ========================================
# Processing the 96 th epoch
# learning rate 0.001
# ========================================
# Processing the 97 th epoch
# learning rate 0.001
# ========================================
# Processing the 98 th epoch
# learning rate 0.001
# ========================================
# Processing the 99 th epoch
# learning rate 0.001
# ========================================
# Processing the 100 th epoch
# learning rate 0.001
# ========================================
# Processing the 101 th epoch
# learning rate 0.001
# epoch: 0101
# cost= 0.003934413
# OFDM Detection QAM output number is 16
# SNR =  25
# Num Pilot 64
# prediction and the mean error on test set are: 0.057817906 0.0625
# BER : 0.0625
# Prediction and the mean error on train set are: 0.006956497 0.0023750067
# ========================================
# Processing the 102 th epoch
# learning rate 0.001
# ========================================
# Processing the 103 th epoch
# learning rate 0.001
# ========================================
# Processing the 104 th epoch
# learning rate 0.001
# ========================================
# Processing the 105 th epoch
# learning rate 0.001
# ========================================
# Processing the 106 th epoch
# learning rate 0.001
# ========================================
# Processing the 107 th epoch
# learning rate 0.001
# ========================================
# Processing the 108 th epoch
# learning rate 0.001
# ========================================
# Processing the 109 th epoch
# learning rate 0.001
# ========================================
# Processing the 110 th epoch
# learning rate 0.001
# ========================================
# Processing the 111 th epoch
# learning rate 0.001
# ========================================
# Processing the 112 th epoch
# learning rate 0.001
# ========================================
# Processing the 113 th epoch
# learning rate 0.001
# ========================================
# Processing the 114 th epoch
# learning rate 0.001
# ========================================
# Processing the 115 th epoch
# learning rate 0.001
# ========================================
# Processing the 116 th epoch
# learning rate 0.001
# ========================================
# Processing the 117 th epoch
# learning rate 0.001
# ========================================
# Processing the 118 th epoch
# learning rate 0.001
# ========================================
# Processing the 119 th epoch
# learning rate 0.001
# ========================================
# Processing the 120 th epoch
# learning rate 0.001
# ========================================
# Processing the 121 th epoch
# learning rate 0.001
# ========================================
# Processing the 122 th epoch
# learning rate 0.001
# ========================================
# Processing the 123 th epoch
# learning rate 0.001
# ========================================
# Processing the 124 th epoch
# learning rate 0.001
# ========================================
# Processing the 125 th epoch
# learning rate 0.001
# ========================================
# Processing the 126 th epoch
# learning rate 0.001
# ========================================
# Processing the 127 th epoch
# learning rate 0.001
# ========================================
# Processing the 128 th epoch
# learning rate 0.001
# ========================================
# Processing the 129 th epoch
# learning rate 0.001
# ========================================
# Processing the 130 th epoch
# learning rate 0.001
# ========================================
# Processing the 131 th epoch
# learning rate 0.001
# ========================================
# Processing the 132 th epoch
# learning rate 0.001
# ========================================
# Processing the 133 th epoch
# learning rate 0.001
# ========================================
# Processing the 134 th epoch
# learning rate 0.001
# ========================================
# Processing the 135 th epoch
# learning rate 0.001
# ========================================
# Processing the 136 th epoch
# learning rate 0.001
# ========================================
# Processing the 137 th epoch
# learning rate 0.001
# ========================================
# Processing the 138 th epoch
# learning rate 0.001
# ========================================
# Processing the 139 th epoch
# learning rate 0.001
# ========================================
# Processing the 140 th epoch
# learning rate 0.001
# ========================================
# Processing the 141 th epoch
# learning rate 0.001
# ========================================
# Processing the 142 th epoch
# learning rate 0.001
# ========================================
# Processing the 143 th epoch
# learning rate 0.001
# ========================================
# Processing the 144 th epoch
# learning rate 0.001
# ========================================
# Processing the 145 th epoch
# learning rate 0.001
# ========================================
# Processing the 146 th epoch
# learning rate 0.001
# ========================================
# Processing the 147 th epoch
# learning rate 0.001
# ========================================
# Processing the 148 th epoch
# learning rate 0.001
# ========================================
# Processing the 149 th epoch
# learning rate 0.001
# ========================================
# Processing the 150 th epoch
# learning rate 0.001
# ========================================
# Processing the 151 th epoch
# learning rate 0.001
# ========================================
# Processing the 152 th epoch
# learning rate 0.001
# ========================================
# Processing the 153 th epoch
# learning rate 0.001
# ========================================
# Processing the 154 th epoch
# learning rate 0.001
# ========================================
# Processing the 155 th epoch
# learning rate 0.001
# ========================================
# Processing the 156 th epoch
# learning rate 0.001
# ========================================
# Processing the 157 th epoch
# learning rate 0.001
# ========================================
# Processing the 158 th epoch
# learning rate 0.001
# ========================================
# Processing the 159 th epoch
# learning rate 0.001
# ========================================
# Processing the 160 th epoch
# learning rate 0.001
# ========================================
# Processing the 161 th epoch
# learning rate 0.001
# ========================================
# Processing the 162 th epoch
# learning rate 0.001
# ========================================
# Processing the 163 th epoch
# learning rate 0.001
# ========================================
# Processing the 164 th epoch
# learning rate 0.001
# ========================================
# Processing the 165 th epoch
# learning rate 0.001
# ========================================
# Processing the 166 th epoch
# learning rate 0.001
# ========================================
# Processing the 167 th epoch
# learning rate 0.001
# ========================================
# Processing the 168 th epoch
# learning rate 0.001
# ========================================
# Processing the 169 th epoch
# learning rate 0.001
# ========================================
# Processing the 170 th epoch
# learning rate 0.001
# ========================================
# Processing the 171 th epoch
# learning rate 0.001
# ========================================
# Processing the 172 th epoch
# learning rate 0.001
# ========================================
# Processing the 173 th epoch
# learning rate 0.001
# ========================================
# Processing the 174 th epoch
# learning rate 0.001
# ========================================
# Processing the 175 th epoch
# learning rate 0.001
# ========================================
# Processing the 176 th epoch
# learning rate 0.001
# ========================================
# Processing the 177 th epoch
# learning rate 0.001
# ========================================
# Processing the 178 th epoch
# learning rate 0.001
# ========================================
# Processing the 179 th epoch
# learning rate 0.001
# ========================================
# Processing the 180 th epoch
# learning rate 0.001
# ========================================
# Processing the 181 th epoch
# learning rate 0.001
# ========================================
# Processing the 182 th epoch
# learning rate 0.001
# ========================================
# Processing the 183 th epoch
# learning rate 0.001
# ========================================
# Processing the 184 th epoch
# learning rate 0.001
# ========================================
# Processing the 185 th epoch
# learning rate 0.001
# ========================================
# Processing the 186 th epoch
# learning rate 0.001
# ========================================
# Processing the 187 th epoch
# learning rate 0.001
# ========================================
# Processing the 188 th epoch
# learning rate 0.001
# ========================================
# Processing the 189 th epoch
# learning rate 0.001
# ========================================
# Processing the 190 th epoch
# learning rate 0.001
# ========================================
# Processing the 191 th epoch
# learning rate 0.001
# ========================================
# Processing the 192 th epoch
# learning rate 0.001
# ========================================
# Processing the 193 th epoch
# learning rate 0.001
# ========================================
# Processing the 194 th epoch
# learning rate 0.001
# ========================================
# Processing the 195 th epoch
# learning rate 0.001
# ========================================
# Processing the 196 th epoch
# learning rate 0.001
# ========================================
# Processing the 197 th epoch
# learning rate 0.001
# ========================================
# Processing the 198 th epoch
# learning rate 0.001
# ========================================
# Processing the 199 th epoch
# learning rate 0.001
# ========================================
# Processing the 200 th epoch
# learning rate 0.001
# ========================================
# Processing the 201 th epoch
# learning rate 0.001
# epoch: 0201
# cost= 0.002874721
# This is a Big Test Set
# OFDM Detection QAM output number is 16
# SNR =  25
# Num Pilot 64
# prediction and the mean error on test set are: 1.5106052e-06 0.0
# BER : 0.0
# Prediction and the mean error on train set are: 0.0032691741 0.0009999871
# ========================================
# Processing the 202 th epoch
# learning rate 0.001
# ========================================
# Processing the 203 th epoch
# learning rate 0.001
# ========================================
# Processing the 204 th epoch
# learning rate 0.001
# ========================================
# Processing the 205 th epoch
# learning rate 0.001
# ========================================
# Processing the 206 th epoch
# learning rate 0.001
# ========================================
# Processing the 207 th epoch
# learning rate 0.001
# ========================================
# Processing the 208 th epoch
# learning rate 0.001
# ========================================
# Processing the 209 th epoch
# learning rate 0.001
# ========================================
# Processing the 210 th epoch
# learning rate 0.001
# ========================================
# Processing the 211 th epoch
# learning rate 0.001
# ========================================
# Processing the 212 th epoch
# learning rate 0.001
# ========================================
# Processing the 213 th epoch
# learning rate 0.001
# ========================================
# Processing the 214 th epoch
# learning rate 0.001
# ========================================
# Processing the 215 th epoch
# learning rate 0.001
# ========================================
# Processing the 216 th epoch
# learning rate 0.001
# ========================================
# Processing the 217 th epoch
# learning rate 0.001
# ========================================
# Processing the 218 th epoch
# learning rate 0.001
# ========================================
# Processing the 219 th epoch
# learning rate 0.001
# ========================================
# Processing the 220 th epoch
# learning rate 0.001
# ========================================
# Processing the 221 th epoch
# learning rate 0.001
# ========================================
# Processing the 222 th epoch
# learning rate 0.001
# ========================================
# Processing the 223 th epoch
# learning rate 0.001
# ========================================
# Processing the 224 th epoch
# learning rate 0.001
# ========================================
# Processing the 225 th epoch
# learning rate 0.001
# ========================================
# Processing the 226 th epoch
# learning rate 0.001
# ========================================
# Processing the 227 th epoch
# learning rate 0.001
# ========================================
# Processing the 228 th epoch
# learning rate 0.001
# ========================================
# Processing the 229 th epoch
# learning rate 0.001
# ========================================
# Processing the 230 th epoch
# learning rate 0.001
# ========================================
# Processing the 231 th epoch
# learning rate 0.001
# ========================================
# Processing the 232 th epoch
# learning rate 0.001
# ========================================
# Processing the 233 th epoch
# learning rate 0.001
# ========================================
# Processing the 234 th epoch
# learning rate 0.001
# ========================================
# Processing the 235 th epoch
# learning rate 0.001
# ========================================
# Processing the 236 th epoch
# learning rate 0.001
# ========================================
# Processing the 237 th epoch
# learning rate 0.001
# ========================================
# Processing the 238 th epoch
# learning rate 0.001
# ========================================
# Processing the 239 th epoch
# learning rate 0.001
# ========================================
# Processing the 240 th epoch
# learning rate 0.001
# ========================================
# Processing the 241 th epoch
# learning rate 0.001
# ========================================
# Processing the 242 th epoch
# learning rate 0.001
# ========================================
# Processing the 243 th epoch
# learning rate 0.001
# ========================================
# Processing the 244 th epoch
# learning rate 0.001
# ========================================
# Processing the 245 th epoch
# learning rate 0.001
# ========================================
# Processing the 246 th epoch
# learning rate 0.001
# ========================================
# Processing the 247 th epoch
# learning rate 0.001
# ========================================
# Processing the 248 th epoch
# learning rate 0.001
# ========================================
# Processing the 249 th epoch
# learning rate 0.001
# ========================================
# Processing the 250 th epoch
# learning rate 0.001
# ========================================
# Processing the 251 th epoch
# learning rate 0.001
# ========================================
# Processing the 252 th epoch
# learning rate 0.001
# ========================================
# Processing the 253 th epoch
# learning rate 0.001
# ========================================
# Processing the 254 th epoch
# learning rate 0.001
# ========================================
# Processing the 255 th epoch
# learning rate 0.001
# ========================================
# Processing the 256 th epoch
# learning rate 0.001
# ========================================
# Processing the 257 th epoch
# learning rate 0.001
# ========================================
# Processing the 258 th epoch
# learning rate 0.001
# ========================================
# Processing the 259 th epoch
# learning rate 0.001
# ========================================
# Processing the 260 th epoch
# learning rate 0.001
# ========================================
# Processing the 261 th epoch
# learning rate 0.001
# ========================================
# Processing the 262 th epoch
# learning rate 0.001
# ========================================
# Processing the 263 th epoch
# learning rate 0.001
# ========================================
# Processing the 264 th epoch
# learning rate 0.001
# ========================================
# Processing the 265 th epoch
# learning rate 0.001
# ========================================
# Processing the 266 th epoch
# learning rate 0.001
# ========================================
# Processing the 267 th epoch
# learning rate 0.001
# ========================================
# Processing the 268 th epoch
# learning rate 0.001
# ========================================
# Processing the 269 th epoch
# learning rate 0.001
# ========================================
# Processing the 270 th epoch
# learning rate 0.001
# ========================================
# Processing the 271 th epoch
# learning rate 0.001
# ========================================
# Processing the 272 th epoch
# learning rate 0.001
# ========================================
# Processing the 273 th epoch
# learning rate 0.001
# ========================================
# Processing the 274 th epoch
# learning rate 0.001
# ========================================
# Processing the 275 th epoch
# learning rate 0.001
# ========================================
# Processing the 276 th epoch
# learning rate 0.001
# ========================================
# Processing the 277 th epoch
# learning rate 0.001
# ========================================
# Processing the 278 th epoch
# learning rate 0.001
# ========================================
# Processing the 279 th epoch
# learning rate 0.001
# ========================================
# Processing the 280 th epoch
# learning rate 0.001
# ========================================
# Processing the 281 th epoch
# learning rate 0.001
# ========================================
# Processing the 282 th epoch
# learning rate 0.001
# ========================================
# Processing the 283 th epoch
# learning rate 0.001
# ========================================
# Processing the 284 th epoch
# learning rate 0.001
# ========================================
# Processing the 285 th epoch
# learning rate 0.001
# ========================================
# Processing the 286 th epoch
# learning rate 0.001
# ========================================
# Processing the 287 th epoch
# learning rate 0.001
# ========================================
# Processing the 288 th epoch
# learning rate 0.001
# ========================================
# Processing the 289 th epoch
# learning rate 0.001
# ========================================
# Processing the 290 th epoch
# learning rate 0.001
# ========================================
# Processing the 291 th epoch
# learning rate 0.001
# ========================================
# Processing the 292 th epoch
# learning rate 0.001
# ========================================
# Processing the 293 th epoch
# learning rate 0.001
# ========================================
# Processing the 294 th epoch
# learning rate 0.001
# ========================================
# Processing the 295 th epoch
# learning rate 0.001
# ========================================
# Processing the 296 th epoch
# learning rate 0.001
# ========================================
# Processing the 297 th epoch
# learning rate 0.001
# ========================================
# Processing the 298 th epoch
# learning rate 0.001
# ========================================
# Processing the 299 th epoch
# learning rate 0.001
# ========================================
# Processing the 300 th epoch
# learning rate 0.001
# ========================================
# Processing the 301 th epoch
# learning rate 0.001
# epoch: 0301
# cost= 0.002608266
# OFDM Detection QAM output number is 16
# SNR =  25
# Num Pilot 64
# prediction and the mean error on test set are: 0.0 0.0
# BER : 0.0
# Prediction and the mean error on train set are: 0.0023836957 0.0009999871
# ========================================
# Processing the 302 th epoch
# learning rate 0.001
# ========================================
# Processing the 303 th epoch
# learning rate 0.001
# ========================================
# Processing the 304 th epoch
# learning rate 0.001
# ========================================
# Processing the 305 th epoch
# learning rate 0.001
# ========================================
# Processing the 306 th epoch
# learning rate 0.001
# ========================================
# Processing the 307 th epoch
# learning rate 0.001
# ========================================
# Processing the 308 th epoch
# learning rate 0.001
# ========================================
# Processing the 309 th epoch
# learning rate 0.001
# ========================================
# Processing the 310 th epoch
# learning rate 0.001
# ========================================
# Processing the 311 th epoch
# learning rate 0.001
# ========================================
# Processing the 312 th epoch
# learning rate 0.001
# ========================================
# Processing the 313 th epoch
# learning rate 0.001
# ========================================
# Processing the 314 th epoch
# learning rate 0.001
# ========================================
# Processing the 315 th epoch
# learning rate 0.001
# ========================================
# Processing the 316 th epoch
# learning rate 0.001
# ========================================
# Processing the 317 th epoch
# learning rate 0.001
# ========================================
# Processing the 318 th epoch
# learning rate 0.001
# ========================================
# Processing the 319 th epoch
# learning rate 0.001
# ========================================
# Processing the 320 th epoch
# learning rate 0.001
# ========================================
# Processing the 321 th epoch
# learning rate 0.001
# ========================================
# Processing the 322 th epoch
# learning rate 0.001
# ========================================
# Processing the 323 th epoch
# learning rate 0.001
# ========================================
# Processing the 324 th epoch
# learning rate 0.001
# ========================================
# Processing the 325 th epoch
# learning rate 0.001
# ========================================
# Processing the 326 th epoch
# learning rate 0.001
# ========================================
# Processing the 327 th epoch
# learning rate 0.001
# ========================================
# Processing the 328 th epoch
# learning rate 0.001
# ========================================
# Processing the 329 th epoch
# learning rate 0.001
# ========================================
# Processing the 330 th epoch
# learning rate 0.001
# ========================================
# Processing the 331 th epoch
# learning rate 0.001
# ========================================
# Processing the 332 th epoch
# learning rate 0.001
# ========================================
# Processing the 333 th epoch
# learning rate 0.001
# ========================================
# Processing the 334 th epoch
# learning rate 0.001
# ========================================
# Processing the 335 th epoch
# learning rate 0.001
# ========================================
# Processing the 336 th epoch
# learning rate 0.001
# ========================================
# Processing the 337 th epoch
# learning rate 0.001
# ========================================
# Processing the 338 th epoch
# learning rate 0.001
# ========================================
# Processing the 339 th epoch
# learning rate 0.001
# ========================================
# Processing the 340 th epoch
# learning rate 0.001
# ========================================
# Processing the 341 th epoch
# learning rate 0.001
# ========================================
# Processing the 342 th epoch
# learning rate 0.001
# ========================================
# Processing the 343 th epoch
# learning rate 0.001
# ========================================
# Processing the 344 th epoch
# learning rate 0.001
# ========================================
# Processing the 345 th epoch
# learning rate 0.001
# ========================================
# Processing the 346 th epoch
# learning rate 0.001
# ========================================
# Processing the 347 th epoch
# learning rate 0.001
# ========================================
# Processing the 348 th epoch
# learning rate 0.001
# ========================================
# Processing the 349 th epoch
# learning rate 0.001
# ========================================
# Processing the 350 th epoch
# learning rate 0.001
# ========================================
# Processing the 351 th epoch
# learning rate 0.001
# ========================================
# Processing the 352 th epoch
# learning rate 0.001
# ========================================
# Processing the 353 th epoch
# learning rate 0.001
# ========================================
# Processing the 354 th epoch
# learning rate 0.001
# ========================================
# Processing the 355 th epoch
# learning rate 0.001
# ========================================
# Processing the 356 th epoch
# learning rate 0.001
# ========================================
# Processing the 357 th epoch
# learning rate 0.001
# ========================================
# Processing the 358 th epoch
# learning rate 0.001
# ========================================
# Processing the 359 th epoch
# learning rate 0.001
# ========================================
# Processing the 360 th epoch
# learning rate 0.001
# ========================================
# Processing the 361 th epoch
# learning rate 0.001
# ========================================
# Processing the 362 th epoch
# learning rate 0.001
# ========================================
# Processing the 363 th epoch
# learning rate 0.001
# ...
# Processing the 4812 th epoch
# ========================================
# Processing the 4813 th epoch
# ========================================
# Processing the 4814 th epoch
# ========================================
# Processing the 4815 th epoch
# ========================================
# Processing the 4816 th epoch
# ========================================
# Processing the 4817 th epoch
# ========================================
# Processing the 4818 th epoch
# ========================================
# Processing the 4819 th epoch
# ========================================
# Processing the 4820 th epoch
# ========================================
# Processing the 4821 th epoch
# ========================================
# Processing the 4822 th epoch
# ========================================
# Processing the 4823 th epoch
# ========================================
# Processing the 4824 th epoch
# ========================================
# Processing the 4825 th epoch
# ========================================
# Processing the 4826 th epoch
# learning rate 1e-05
# ========================================
# Processing the 4827 th epoch
# ========================================
# Processing the 4828 th epoch
# ========================================
# Processing the 4829 th epoch
# ========================================
# Processing the 4830 th epoch
# ========================================
# Processing the 4831 th epoch
# ========================================
# Processing the 4832 th epoch
# ========================================
# Processing the 4833 th epoch
# ========================================
# Processing the 4834 th epoch
# ========================================
# Processing the 4835 th epoch
# ========================================
# Processing the 4836 th epoch
# ========================================
# Processing the 4837 th epoch
# ========================================
# Processing the 4838 th epoch
# ========================================
# Processing the 4839 th epoch
# ========================================
# Processing the 4840 th epoch
# ========================================
# Processing the 4841 th epoch
# ========================================
# Processing the 4842 th epoch
# ========================================
# Processing the 4843 th epoch
# ========================================
# Processing the 4844 th epoch
# ========================================
# Processing the 4845 th epoch
# ========================================
# Processing the 4846 th epoch
# ========================================
# Processing the 4847 th epoch
# ========================================
# Processing the 4848 th epoch
# ========================================
# Processing the 4849 th epoch
# ========================================
# Processing the 4850 th epoch
# ========================================
# Processing the 4851 th epoch
# learning rate 1e-05
# ========================================
# Processing the 4852 th epoch
# ========================================
# Processing the 4853 th epoch
# ========================================
# Processing the 4854 th epoch
# ========================================
# Processing the 4855 th epoch
# ========================================
# Processing the 4856 th epoch
# ========================================
# Processing the 4857 th epoch
# ========================================
# Processing the 4858 th epoch
# ========================================
# Processing the 4859 th epoch
# ========================================
# Processing the 4860 th epoch
# ========================================
# Processing the 4861 th epoch
# ========================================
# Processing the 4862 th epoch
# ========================================
# Processing the 4863 th epoch
# ========================================
# Processing the 4864 th epoch
# ========================================
# Processing the 4865 th epoch
# ========================================
# Processing the 4866 th epoch
# ========================================
# Processing the 4867 th epoch
# ========================================
# Processing the 4868 th epoch
# ========================================
# Processing the 4869 th epoch
# ========================================
# Processing the 4870 th epoch
# ========================================
# Processing the 4871 th epoch
# ========================================
# Processing the 4872 th epoch
# ========================================
# Processing the 4873 th epoch
# ========================================
# Processing the 4874 th epoch
# ========================================
# Processing the 4875 th epoch
# ========================================
# Processing the 4876 th epoch
# learning rate 1e-05
# ========================================
# Processing the 4877 th epoch
# ========================================
# Processing the 4878 th epoch
# ========================================
# Processing the 4879 th epoch
# ========================================
# Processing the 4880 th epoch
# ========================================
# Processing the 4881 th epoch
# ========================================
# Processing the 4882 th epoch
# ========================================
# Processing the 4883 th epoch
# ========================================
# Processing the 4884 th epoch
# ========================================
# Processing the 4885 th epoch
# ========================================
# Processing the 4886 th epoch
# ========================================
# Processing the 4887 th epoch
# ========================================
# Processing the 4888 th epoch
# ========================================
# Processing the 4889 th epoch
# ========================================
# Processing the 4890 th epoch
# ========================================
# Processing the 4891 th epoch
# ========================================
# Processing the 4892 th epoch
# ========================================
# Processing the 4893 th epoch
# ========================================
# Processing the 4894 th epoch
# ========================================
# Processing the 4895 th epoch
# ========================================
# Processing the 4896 th epoch
# ========================================
# Processing the 4897 th epoch
# ========================================
# Processing the 4898 th epoch
# ========================================
# Processing the 4899 th epoch
# ========================================
# Processing the 4900 th epoch
# ========================================
# Processing the 4901 th epoch
# learning rate 1e-05
# epoch: 4901
# cost= 0.007850244
# OFDM Detection QAM output number is 16
# SNR =  25
# Num Pilot 64
# prediction and the mean error on test set are: 0.022341779 0.0
# BER : 0.0
# Prediction and the mean error on train set are: 0.0162101 0.012125015
# ========================================
# Processing the 4902 th epoch
# ========================================
# Processing the 4903 th epoch
# ========================================
# Processing the 4904 th epoch
# ========================================
# Processing the 4905 th epoch
# ========================================
# Processing the 4906 th epoch
# ========================================
# Processing the 4907 th epoch
# ========================================
# Processing the 4908 th epoch
# ========================================
# Processing the 4909 th epoch
# ========================================
# Processing the 4910 th epoch
# ========================================
# Processing the 4911 th epoch
# ========================================
# Processing the 4912 th epoch
# ========================================
# Processing the 4913 th epoch
# ========================================
# Processing the 4914 th epoch
# ========================================
# Processing the 4915 th epoch
# ========================================
# Processing the 4916 th epoch
# ========================================
# Processing the 4917 th epoch
# ========================================
# Processing the 4918 th epoch
# ========================================
# Processing the 4919 th epoch
# ========================================
# Processing the 4920 th epoch
# ========================================
# Processing the 4921 th epoch
# ========================================
# Processing the 4922 th epoch
# ========================================
# Processing the 4923 th epoch
# ========================================
# Processing the 4924 th epoch
# ========================================
# Processing the 4925 th epoch
# ========================================
# Processing the 4926 th epoch
# learning rate 1e-05
# ========================================
# Processing the 4927 th epoch
# ========================================
# Processing the 4928 th epoch
# ========================================
# Processing the 4929 th epoch
# ========================================
# Processing the 4930 th epoch
# ========================================
# Processing the 4931 th epoch
# ========================================
# Processing the 4932 th epoch
# ========================================
# Processing the 4933 th epoch
# ========================================
# Processing the 4934 th epoch
# ========================================
# Processing the 4935 th epoch
# ========================================
# Processing the 4936 th epoch
# ========================================
# Processing the 4937 th epoch
# ========================================
# Processing the 4938 th epoch
# ========================================
# Processing the 4939 th epoch
# ========================================
# Processing the 4940 th epoch
# ========================================
# Processing the 4941 th epoch
# ========================================
# Processing the 4942 th epoch
# ========================================
# Processing the 4943 th epoch
# ========================================
# Processing the 4944 th epoch
# ========================================
# Processing the 4945 th epoch
# ========================================
# Processing the 4946 th epoch
# ========================================
# Processing the 4947 th epoch
# ========================================
# Processing the 4948 th epoch
# ========================================
# Processing the 4949 th epoch
# ========================================
# Processing the 4950 th epoch
# ========================================
# Processing the 4951 th epoch
# learning rate 1e-05
# ========================================
# Processing the 4952 th epoch
# ========================================
# Processing the 4953 th epoch
# ========================================
# Processing the 4954 th epoch
# ========================================
# Processing the 4955 th epoch
# ========================================
# Processing the 4956 th epoch
# ========================================
# Processing the 4957 th epoch
# ========================================
# Processing the 4958 th epoch
# ========================================
# Processing the 4959 th epoch
# ========================================
# Processing the 4960 th epoch
# ========================================
# Processing the 4961 th epoch
# ========================================
# Processing the 4962 th epoch
# ========================================
# Processing the 4963 th epoch
# ========================================
# Processing the 4964 th epoch
# ========================================
# Processing the 4965 th epoch
# ========================================
# Processing the 4966 th epoch
# ========================================
# Processing the 4967 th epoch
# ========================================
# Processing the 4968 th epoch
# ========================================
# Processing the 4969 th epoch
# ========================================
# Processing the 4970 th epoch
# ========================================
# Processing the 4971 th epoch
# ========================================
# Processing the 4972 th epoch
# ========================================
# Processing the 4973 th epoch
# ========================================
# Processing the 4974 th epoch
# ========================================
# Processing the 4975 th epoch
# ========================================
# Processing the 4976 th epoch
# learning rate 1e-05
# ========================================
# Processing the 4977 th epoch
# ========================================
# Processing the 4978 th epoch
# ========================================
# Processing the 4979 th epoch
# ========================================
# Processing the 4980 th epoch
# ========================================
# Processing the 4981 th epoch
# ========================================
# Processing the 4982 th epoch
# ========================================
# Processing the 4983 th epoch
# ========================================
# Processing the 4984 th epoch
# ========================================
# Processing the 4985 th epoch
# ========================================
# Processing the 4986 th epoch
# ========================================
# Processing the 4987 th epoch
# ========================================
# Processing the 4988 th epoch
# ========================================
# Processing the 4989 th epoch
# ========================================
# Processing the 4990 th epoch
# ========================================
# Processing the 4991 th epoch
# ========================================
# Processing the 4992 th epoch
# ========================================
# Processing the 4993 th epoch
# ========================================
# Processing the 4994 th epoch
# ========================================
# Processing the 4995 th epoch
# ========================================
# Processing the 4996 th epoch
# ========================================
# Processing the 4997 th epoch
# ========================================
# Processing the 4998 th epoch
# ========================================
# Processing the 4999 th epoch
# ========================================
# Processing the 5000 th epoch
# Total epochs cost :
#  [[0.252912   0.01429591 0.00719745 0.00485478 0.00393441 0.00337149
#   0.00304954 0.00298648 0.00287472 0.00277537 0.00268473 0.00263441
#   0.00260827 0.00246393 0.00228434 0.00245258 0.00237195 0.00238299
#   0.0023421  0.00237575 0.00233316 0.00212022 0.00234581 0.00234779
#   0.00237147 0.00228586 0.00220529 0.0021458  0.00214506 0.0024172
#   0.00213636 0.00221258 0.00216384 0.0021167  0.00206102 0.00222984
#   0.00227141 0.00220035 0.00207931 0.00203972 0.00210695 0.00215109
#   0.00210051 0.00213833 0.00208945 0.00224378 0.00212483 0.00214377
#   0.00200917 0.00223188 0.00204918 0.00204926 0.00198231 0.0021635
#   0.00189874 0.00203743 0.00204744 0.00192959 0.00196211 0.00190182
#   0.00181385 0.00198996 0.00196828 0.00187652 0.00196248 0.00193524
#   0.00207606 0.00202059 0.0018325  0.0018668  0.00186654 0.00191791
#   0.00193794 0.00199191 0.0018108  0.00173215 0.00177946 0.00174146
#   0.00182003 0.00181875 0.001944   0.02105276 0.02094697 0.02112759
#   0.0208493  0.02076698 0.01994818 0.01957923 0.01811956 0.01821857
#   0.01762074 0.01604109 0.0146528  0.01397755 0.01287097 0.01271129
#   0.01265746 0.01206735 0.01252546 0.01190664 0.01190437 0.01208142
#   0.01164946 0.01094535 0.01147063 0.01092328 0.01048336 0.01082969
#   0.01095416 0.0104523  0.01027799 0.01054972 0.01056501 0.00996774
#   0.0105284  0.0103047  0.00985494 0.01027788 0.00972801 0.01004042
#   0.00976172 0.00969298 0.0097314  0.00965402 0.00949896 0.00963789
#   0.00953367 0.00957293 0.00983483 0.00942433 0.00976807 0.00941215
#   0.00964115 0.0093076  0.00936998 0.00909722 0.00918458 0.00965686
#   0.00889732 0.00900505 0.0090446  0.00886806 0.00905874 0.00919678
#   0.00886582 0.00843214 0.00852811 0.00872065 0.00872491 0.00852104
#   0.00854461 0.00903677 0.00833572 0.00823178 0.00835507 0.00858305
#   0.00838584 0.00853565 0.00819804 0.00886549 0.00838637 0.00819282
#   0.00812264 0.0081068  0.00803278 0.00823756 0.00829719 0.00822074
#   0.008136   0.0083011  0.00828331 0.00811568 0.00791048 0.00799635
#   0.00828694 0.00817313 0.00790304 0.00818058 0.00820162 0.00832725
#   0.00774716 0.00786355 0.00810253 0.00803567 0.0082797  0.00805239
#   0.00843574 0.00835489 0.007837   0.00802004 0.0077792  0.00803143
#   0.00779177 0.00787523 0.00769332 0.00786016 0.00785024 0.00824526
#   0.00794404 0.00777805]]
# optimization finished
# Save to path:  net_BG_finetune_25dB_p_0001_var_2_real/epochs_5000.ckpt
# Wall time: 21h 23min 39s

# %% [markdown]
# # Part IV : Testing the model

# %%
# %%time
with tf.Session() as sess:
    saver.restore(sess, "net_Impulse_thesis/epochs_5000.ckpt")
    for k in range(5,31): # (5,26)
        SNRdB=k   # SNRdB=k
        input_samples_test = []
        input_labels_test = []
        test_number = 10000         # 1000 
        for i in range(0, test_number):
            bits = np.random.binomial(n=1, p=0.5, size=(payloadBits_per_OFDM, ))  
            channel_response= channel_response_set_test[np.random.randint(0,len(channel_response_set_test))]
            signal_output, para = ofdm_simulate_BG(bits,channel_response,SNRdB)
            input_labels_test.append(bits[16:32])
            input_samples_test.append(signal_output)

        batch_x = np.asarray(input_samples_test)
        batch_y = np.asarray(input_labels_test)
        y_pred_np=y_pred.eval({X:batch_x})            # LJS
        BER=decision(y_pred_np,batch_y)               # LJS
        print('SNR = ',SNRdB,'BER :',BER)             # LJS
# Out:
# INFO:tensorflow:Restoring parameters from net_BG_finetune_25dB_p_0001_var_2_real/epochs_5000.ckpt
# SNR =  5 BER : 0.1074125
# SNR =  6 BER : 0.08925
# SNR =  7 BER : 0.07356875
# SNR =  8 BER : 0.060175
# SNR =  9 BER : 0.04829375
# SNR =  10 BER : 0.04078125
# SNR =  11 BER : 0.03243125
# SNR =  12 BER : 0.0264375
# SNR =  13 BER : 0.02221875
# SNR =  14 BER : 0.018925
# SNR =  15 BER : 0.01709375
# SNR =  16 BER : 0.01408125
# SNR =  17 BER : 0.01201875
# SNR =  18 BER : 0.01011875
# SNR =  19 BER : 0.0090625
# SNR =  20 BER : 0.00909375
# SNR =  21 BER : 0.0081375
# SNR =  22 BER : 0.00725
# SNR =  23 BER : 0.00644375
# SNR =  24 BER : 0.0062875
# SNR =  25 BER : 0.00615
# SNR =  26 BER : 0.00563125
# SNR =  27 BER : 0.005425
# SNR =  28 BER : 0.00575625
# SNR =  29 BER : 0.00529375
# SNR =  30 BER : 0.005575
# SNR =  31 BER : 0.00555
# SNR =  32 BER : 0.0053875
# SNR =  33 BER : 0.00553125
# SNR =  34 BER : 0.00510625
# SNR =  35 BER : 0.00483125
# SNR =  36 BER : 0.00451875
# SNR =  37 BER : 0.004775
# SNR =  38 BER : 0.005375
# SNR =  39 BER : 0.0047375
# SNR =  40 BER : 0.00465
# SNR =  41 BER : 0.0051625
# SNR =  42 BER : 0.0051875
# SNR =  43 BER : 0.00468125
# SNR =  44 BER : 0.004575
# SNR =  45 BER : 0.00505
# Wall time: 6min 43s

# %% [markdown]
# # -----------------------------------------Programs end-----------------------------------------

# %%
g=10
for i in range(100):
    print('i :',i)
    if i >= 5 :
        if i % 5 == 0 :
            g=g+1
    print('g :',g)
    if g >=15 :
        break
# Out:
# i : 0
# g : 10
# i : 1
# g : 10
# i : 2
# g : 10
# i : 3
# g : 10
# i : 4
# g : 10
# i : 5
# g : 11
# i : 6
# g : 11
# i : 7
# g : 11
# i : 8
# g : 11
# i : 9
# g : 11
# i : 10
# g : 12
# i : 11
# g : 12
# i : 12
# g : 12
# i : 13
# g : 12
# i : 14
# g : 12
# i : 15
# g : 13
# i : 16
# g : 13
# i : 17
# g : 13
# i : 18
# g : 13
# i : 19
# g : 13
# i : 20
# g : 14
# i : 21
# g : 14
# i : 22
# g : 14
# i : 23
# g : 14
# i : 24
# g : 14
# i : 25
# g : 15
